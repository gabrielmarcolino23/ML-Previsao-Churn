# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_json('Telco-Customer-Churn-limpeza.json')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID_Cliente                7043 non-null   object
#  1   Churn                     7043 non-null   object
#  2   Genero                    7043 non-null   object
#  3   Idoso                     7043 non-null   object
#  4   Parceiro                  7043 non-null   object
#  5   Dependentes               7043 non-null   object
#  6   Meses_na_Empresa          7043 non-null   int64
#  7   Servico_Telefonico        7043 non-null   object
#  8   Multiplas_Linhas          7043 non-null   object
#  9   Servico_Internet          7043 non-null   object
#  10  Servico_Seguranca_Online  7043 non-null   object
#  11  Backup_Online             7043 non-null   object
#  12  Protecao_Dispositivo      7043 non-null   object
# ...

# %%
dados.head()
# Out:
#    ID_Cliente Churn  Genero Idoso Parceiro Dependentes  Meses_na_Empresa  \
# 0  0002-ORFBO    No  Female    No      Yes         Yes                 9
# 1  0003-MKNFE    No    Male    No       No          No                 9
# 2  0004-TLHLJ   Yes    Male    No       No          No                 4
# 3  0011-IGKFF   Yes    Male   Yes      Yes          No                13
# 4  0013-EXCHZ   Yes  Female   Yes      Yes          No                 3
#
#   Servico_Telefonico Multiplas_Linhas Servico_Internet  ...  \
# 0                Yes               No              DSL  ...
# 1                Yes              Yes              DSL  ...
# 2                Yes               No      Fiber optic  ...
# 3                Yes               No      Fiber optic  ...
# 4                Yes               No      Fiber optic  ...
#
#   Protecao_Dispositivo Suporte_Tecnico TV_Streaming Filmes_Streaming  \
# 0                   No             Yes          Yes               No
# ...

# %%
# N de churn
sns.set(style="darkgrid")

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Churn', hue='Churn', data=dados, palette='viridis', dodge=False)

ax.set_title('Distribuição de Churn')
ax.set_ylabel('Quantidade')

for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', color='white', size=12)

plt.show()

# %%
# Distribuição de churn por gênero

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Genero', hue='Churn', data=dados, palette='viridis')

# Adicionando títulos e rótulos
ax.set_title('Distribuição de Churn por Gênero')
ax.set_xlabel('Churn')
ax.set_ylabel('Quantidade')

# Mostrando o numero de cada barra
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', color='white', size=12)

# Mostrando o gráfico
plt.show()

# %%
# Churn por plano

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Contrato', hue='Churn', data=dados, palette='viridis')

# Adicionando títulos e rótulos
ax.set_title('Distribuição de Churn por Plano')
ax.set_xlabel('Plano')
ax.set_ylabel('Quantidade')

# Mostrando o numero de cada barra
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', color='white', size=12)

plt.show()

# %%
# Churn por Serviço de intenet

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Servico_Internet', hue='Churn', data=dados, palette='viridis')

# Adicionando títulos e rótulos
ax.set_title('Distribuição de Churn por Serviço de Internet')
ax.set_xlabel('Serviço de Internet')
ax.set_ylabel('Quantidade')

# Mostrando o numero de cada barra
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', color='white', size=8)

plt.show()

# %%
# Churn entre idosos

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Idoso', hue='Churn', data=dados, palette='viridis')

# Adicionando títulos e rótulos
ax.set_title('Distribuição de Churn por Idosos')
ax.set_xlabel('Idosos')
ax.set_ylabel('Quantidade')

# Mostrando o numero de cada barra
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', color='white', size=12)

plt.show()

# %%
# Distribuição de churn por forma de metodo

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Metodo_Pagamento', hue='Churn', data=dados, palette='viridis')

# Adicionando títulos e rótulos
ax.set_title('Distribuição de Churn por Metodo de Pagamento')
ax.set_xlabel('Metodo de Pagamento')
ax.set_ylabel('Quantidade')

# Mostrando o numero de cada barra
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', color='white', size=8)

plt.show()

# %%
# Box plot das variasveis numericas

plt.figure(figsize=(10, 6))
ax = sns.boxplot(y='Churn', x='Meses_na_Empresa', hue='Churn', data=dados, palette='viridis')

# Adicionando títulos e rótulos
ax.set_title('Boxplot de Churn por Tempo de Contrato')
ax.set_xlabel('Churn')
ax.set_ylabel('Tempo de Contrato')

plt.show()

# %%
# Boxplot gasto mensal

plt.figure(figsize=(10, 6))
ax = sns.boxplot(y='Churn', x='Cobranca_Mensal', hue='Churn', data=dados, palette='viridis')

# Adicionando títulos e rótulos
ax.set_title('Boxplot de Churn por Gasto Mensal')
ax.set_xlabel('Churn')
ax.set_ylabel('Gasto Mensal')

plt.show()
